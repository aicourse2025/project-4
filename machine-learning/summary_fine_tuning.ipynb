# %% [markdown]
# ## Summary generation

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
#get cleaned and clustered dataset of Amazon reviews
import pandas as pd

dataset_reviews = pd.read_csv("../data/top3_products.csv")  # replace with your actual path

# print(dataset_reviews[:1])
print(dataset_reviews.columns)
dataset_reviews.head()
# Out:
# Index(['asins', 'name', 'cluster_name', 'rating_mean', 'rating_count',
#        'imageURLs', 'weighted_score', 'positive_reviews', 'negative_reviews'],
#       dtype='object')
#                    asins                                               name  \
# 0             B00OQVZDJM  Amazon Kindle Paperwhite - eBook reader - 4 GB...
# 1             B00IOY8XWQ  Kindle Voyage E-reader, 6 High-Resolution Disp...
# 2             B00IOYAM4I  Kindle Voyage E-reader, 6 High-Resolution Disp...
# 3  B018SZT3BK,B01AHB9CN2  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4             B01J94YIT6  All-New Fire HD 8 Tablet with Alexa, 8 HD Disp...
#
#                 cluster_name  rating_mean  rating_count  \
# 0  E-Reader & Office Tablets         4.77          3175
# 1  E-Reader & Office Tablets         4.73           599
# 2  E-Reader & Office Tablets         4.86            51
# 3      Entertainment Tablets         4.58          2368
# 4      Entertainment Tablets         4.58           831
#
#                                            imageURLs  weighted_score  \
# 0                                                NaN        4.732904
# 1  https://i5.walmartimages.com/asr/5bb13520-39a6...        4.624555
# 2  http://pisces.bbystatic.com/image2/BestBuy_US/...        4.532403
# 3  https://www.barcodable.com/images/barcode/0841...        4.565829
# 4  https://www.barcodable.com/images/barcode/0841...        4.549514
#
#                                     positive_reviews  \
# 0  daughter 's 1st kindle several kindle version ...
# 1  amazing portable lightweight third amazon kind...
# 2  expect improvement pricey yes ... serious read...
# 3  7 year old granddaughter love request 7 yr old...
# 4  a+ using couple 'cheaper generic android table...
#
#                                     negative_reviews
# 0  transfer library book via usb purchased ereade...
# 1  amazon voyage dead trying update software kind...
# 2                                                NaN
# 3  color difference huge bad customer service got...
# 4  stopped charging 6 month amazon fire hd 8 tabl...

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)


def get_completion(prompt, model="gpt-3.5-turbo"): 
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
dataset_reviews["prompt"] = dataset_reviews["positive_reviews"].fillna("") + "\n" + dataset_reviews["negative_reviews"].fillna("")
# dataset_reviews["target"] = "Summarize the product based on the reviews."

# %%
for category, group in dataset_reviews.groupby("name"):
    combined_reviews = " ".join(group["prompt"].astype(str).tolist())

    # prompt_1 = f"""
    # Your task is to generate a short summary of the three products from a single category.
    # It should read like a review.
    # Write it in the style of product reviews on Consumer Reviews website, The Verge, The Wirecutter.

    # What are the best qualities of each of those products?
    # You should also identify top complaints for each of those products.
    # What is the worst product in the category and why you should never buy it.

    # Summarize the review below, delimited by triple backticks, in at most 200 words.

    # Review: ```{combined_reviews}```
    # """


    prompt_1 = f"""
    You are an expert product reviewer writing a concise blog post to help customers choose the best product.

1. **Top 3 products in this category:**  
   - List the top 3 products.  
   - Highlight their key differences and unique selling points.  
   - Explain when a customer should choose one product over the others.

2. **Top complaints for each product:**  
   - Summarize the most common issues customers mention for each product.

3. **Worst product in the category:**  
   - Identify the product with the most negative feedback or poorest performance.  
   - Explain why customers should avoid it.

4. **Additional insights:**  
   - Include any recurring themes or patterns from the reviews.  
   - Mention notable features that impress or frustrate customers.  
   - Provide practical advice based on customer experiences.

---
Product 1: Echo (White)
Positive Reviews: love echo want device performs command alexa name.she 's constant companion kitchen sings tell joke share recipe tell story quote bible verse give weather forecast much more.if add additional device control light thermostat grandson really like alexa tell stories.this inanimate object begin feel like real person longer around love ... amazon echo become critical appliance kitchen admittedly bought echo serve yet another cool toy around ... 're finding 's great addition lives.the top used function family probably simple use timer function close second ability call artist want hear amazon prime music 's well worth buck month get music service sound quality device although audiophile worthy quite good.our family still exploring many great tool available alexa ... say without reservation 's great device household forget 's like alexa around alexa transformed life home chooses music listen `` alexa play music '' keep track shopping `` alexa reorder cat food '' make sure n't burn dinner `` alexa set 15 minute timer '' ... find asking thing 'm home disappointed n't looking forward buying `` smart home '' item help use even amazing echo amazon echo amazing also somewhat frustrating experience convenience brings timer turning connected light playing music corny joke amazing love machine also become little frustrating n't work immediately time 've mostly worked first try definitely day light wo n't turn asked sometimes take long time alexa respond command could internet issue still detracts experience awesome device enjoyed immensely useful informative entertaining part daily life giving u news update locally world information anything ask like word definition synonym antonym math science educational question ... name 's like book encyclopedia course entertainment-playing music bluetooth connection and/or amazon music playlist great amazing gadget whole family buy another one pretty decent information gathering tool bought two echo one wife one expected something along line siri google could follow many command say specific command get response also echo cant distinguish commercial one commercial come try answer question hears alexa also trying set wife 's echo phone calling ca n't pull page setup option there.we like still trying learn easy home automation starting point easy setup.easily connected home harmony setup gave u reason get phillip hue light could happier alexa work great `` '' time found location key especially playing tv alexa sometimes gear voice due location close speaker moved work better always getting better .... echo call soon video another device echo product ... amazon amazon cell phone fun productive bought gag gift wife returned gift bottle perfume us device every day music play shopping list get made daily news caught time alexa pretty good converting unit cook need know many tablespoon liter handsfree timer request easy find looking way add clever little device would highly recommend fact 'm buy one parent great product around purchased amazon echo mother 's day gift wife quickly become gift entire family sound quality speaker average play music either iheart radio connected bluetooth device quickly connects wifi house portable n't used alexa many home automated function light electronic ordering food online etc purchase wifi outlet likely try technology overall happy product lot fun lot fun play music game weather much however making phone call text message hope develop way determine able send text message phone call make call anyone choose united state app device feel google may better device advanced database sometimes alexa understand asking would think would able know fun however would 've probably purchased google tell probably able play music
Negative Reviews: work properly device stay connected wifi always disconnecting make product unusable alarm timer used work harmony time turn device priced overrated purchased google home past week lost contact wifi work perfectly harmony hub difficult setup echo even 5-6 time echo support ca n't figure wish could return late purchased without research unimpressed found opened tried programming awesome alexa basically nothing come 's listening device home wo n't anything unless pay amazon fact synced pandora account pointless spell want alexa play saying `` alexa play x station pandora play list '' rest family suppose know request one know pandora play list barely many complaint basically disappointed purchase lead believe radio future pay amazon music unlimited monthly bluetooth bummer on/off timer wonderfully designed device use fairly limited bought primarily use smart home control device however although allows turn light add timer control instruction instance tell echo turn light 30 minute tell turn immediately finding incredible disappointing n't know understand would hard add feature useless without prime matter asked either alexa n't know answer offered order item n't ask prime membership.could n't even get weather forecast right.kept giving forcast area 20 mile away.i returned it.by way whatever ask '' ok google '' get answer usually 99 correct.never asks pay 99 membership offer order something online me.do n't need n't want n't waste money could give lower rating would.this nothing speaker big one.it wireless even take outside w/o power source ask question alexa search answer expensive would like try google since return ca n't justify price everyone said give time like alexa gave much time realize return within time frame bad knowledgable many question miss interpreted replied understanding looking distance hear u minimal returned one purchased `` google '' one much better knowledgeable answer device recommend using phone app also making purchase usage item may available n't expect additional charge 'm thrilled either one keep google device hope better come future alexa malexa item useless play music voice recognition unless pay amazon prime amazon music account disconnected play music manual control blue tooth connection phone pointless half question ask n't know answer thing 's good far time weather basically expensive blue tooth speaker clock ever purchased want money back intuitive overly argumentative purchased item recommendation many existing owner however got home attempted set device frustrating instructions/faqs helpful echo could find nest thermostat could find half hue light argued fought alexa 45 minute finally started pick light comletely re-configuring thermostat could see would work found light would turn would change color brightness level run software company worked computer whole life quirky would recommend item get google home

---

Product 2: Amazon - Echo Plus w/ Built-In Hub - Silver
Positive Reviews: alexa rock present husband originally asked radio home office set relatively quick amazed sound quality loved versatility could specific radio station played random song well tell joke etc fun u looking getting smaller `` dot '' room commented would never get rid 's fun functional smart bulb handy well love amazon echo plus awesome purchased two amazon echo plus two dot plus four fire stick hub philip hue lamp family christmas 2017. i⊙m happy purchase learning much alexa start daily routine alexa program whatever would like include news weather music horoscope also start day compliment think important alexa gave best chili recipe mean best it⊙s called chili i. want husband use alexa stay organized business date reminder way go alexa review yesterday evening decided purchase amazon echo machine intrusive yeah guess could allow purchased home automation fantastic capability name capability subscription unprecedented amount music listen worth thing include sport travel recipe traffic home automation part lock door turn light random lighting vacation .. amazon echo plus wow echo plus demonstrated u best buy bit skeptical bought check wow impressed tell turn turn light living room family room bedroom also dim light need local weather forecast ask want listen christmas music yes want know distance someplace population city country yes 're still discovering seems limitless absolutely love amazon echo smart device hub take echo 've amazon echo dot year really wanted develop smart device usage around house upgraded echo great device use drop feature communicate others house especially upstairs without yell smart hub amazing attaching smart device much seamless 1st gen echo got time tell 2nd gen echo device worth echo plus purchased echo plus reading new generation upgraded improving sound integration controller price provided thought deal good value first generation unit well quick comparison two sound look etc perspective really n't lead think noticeable sound improvement improved aesthetic least price unit come quite bit addition philip bulb 'free smart move.overall think unit good purchase beginning home automation project alexa awesome joke rapping everyday new fact alexa awesome super easy pull phone check weather honestly never would always surprised walked outside whatever day every morning ask alexa whats weather give depth review day rest week ton skill alexa useful random shes must try also plus echo plus want start smart home dont need hub like echo piece buy compatible smart bulb nice update additional original echo like idea built-in hub control smart home device get them.sound quality marginally better n't buy echo audiophiles ... background music 's perfect that.my complaint date account home amazon echo must one make frustrating user particularly playing configuring music play room excited expand smart capability echo plus fantastically easy use smarthome hub easy setup fast responsive ton capability expanding daily look sound great currently use mine manage smart ⊜things⊝ like light bulb lamp smart switch even robot vac made automating lot daily breeze simplified life didn⊙t know needed simplified definitely worth extra money go plus echo dot love alexa echo plus alight 's becoming part family echo plus much different discovered yet anyway echo 2nd generation n't echo 1st generation know echo plus echos-2nd generation dot 3 week thing think make difference better sound quality talking really connoisseur kind ear one like turn volume hue lightbulb great bought echo plus black friday extended sale hue lightbulb real bonus liked much went back bought pack hue bulb also sale loving whole system lightbulbNegative Reviews: /
Negative Reviews: /

---

Product 3: Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen
Positive Reviews: practical easy setup well designed good sound everything alexa plus hd video always ready answer associated video text applicable show movie trailer also watch amazon video excellent on-demand security video amazon compatible camera voice activated message and/or video call amazon show owner alexa app holder highly recommended simple powerful little hesitant spend money get glad alexa always answer say command noticed probably 95 right command given love fact see thing screen news briefing picture/video 's nice also love video call option planning getting one grandma technologically advanced could sit table talk grandkids worth every penny terrific product jealous son showed u amazon show thing capable since aol eliminated instant messaging wife less able communicate office separate floor got two show two spot intercom easily use alexa music many thing probably start using smart home device alexa also control 's fun device seems getting better time returned nucleus gem beauty previously owned nucleus device similar device great device lot bug much returned device masterpiece tied alexa echo universe used intercom throughout house echo also used view thing even call people echo directly amazing piece hardware amazon proud developing beautiful device echo show first concerned funny looking angle saw picture item displayed local store decided take chance owner echo dot figured would work manner love work arlo pro screen great soon figured reason funny angle item angled screen work great setback recommendation would add auxiliary output rear also watch prime movie youtube video etc overall excellent product amazon 9.5/10 rating one best ai product used screen smart home device useful really ca n't compete google home show brings convenience without call primarily use show turn on/off smart light simple cooking measurement simple math travel time store location hour calling video calling .... everything else like news calendar weather already displayed screen definitely worth plan using minimum feature great addition amazon echo family love amazon echo show video display helpful good quality video audio sound better echo plus speaker search recipe use without flipping recipe book need know measurement conversion ask alexa learn cooking technique recommended cooking time ... endless list available answer great addition kitchen love play christmas music throughout home using echo device lot fun work like echo product .with smart accessory control home thermostat light etc alot expandable option feature expected already 6 amazon device 2 echo 's 4 dot 's expected device slightly different amazon device screen pleasantly surprised large number helpful feature screen could bring occasionally scroll suggestion across screen helpful 'm planning setting another one 93 year old mother house 'll get kick also delivers promise despite less friendly price point n't get sale amazon item well designed delivers promise hype product description emphasis item `` show '' 's surprise sound quality compare echo want convenience voice controlled screen phone product delivers 's value even greater paired smart device security cam another added bonus come friend family also show `` drop '' essentially visual phone call 's great checking elderly family require technically savvy best echo kitchen/living room lot echo device room house kind smart speaker also google home device .the echo show best device use living room kitchen screen bright sharp 's nice feature follow recipe watch video even listen music lyric displayed screen.it 's also best way see calendar entry shopping list
Negative Reviews: pas waited couple month review giving amazon time make product equal sony dash nearly decade ago n't screen provides nothing value ca n't turn amazon tip near zero customization ca n't even move clock side screen something sony dash nearly 10 year ago pandora prime music alarm seriously biggest fail run away half baked amazon disaster less useless doesn⊙t work cloudcam less useless work amazon cloudcam purchased best buy allow monitor two cloud cam kitchen tech savvy numerous alexa device unable get work tried installing enabling amazon cloudcam skill made sure new update show show automatically updated first plugged final straw tech support rep told can⊙t use show cloudcam⊔and unable connect someone could actually solve problem useless help less useless actually make work echo show less useless
Please write the blog-style review article based on these reviews.


    Review: ```{combined_reviews}```
    """

    response = get_completion(prompt_1)
    print(f"\n=== Summary for Category: {category} ===\n")
    print(response)

"""
Your task is to generate a short summary of the three product from a single category \
It should read like a review.
Write it in the style of product reviews on Consumer Reviews website, The Verge, The Wirecutter

What are the best qualities of each of those products.
You should also identify top complaints for each of those products.
What is the worst product in the category and why you should never buy it

Summarize the review below, delimited by triple 
backticks, in at most 200 words. 

Review: ```{dataset_reviews["prompt"]}```
"""
# Out:
# === Summary for Category: All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Blue Kid-Proof Case ===
#
# If you're in the market for a kid-friendly tablet, the Amazon Fire HD 8 Kids Edition is a top choice. With parental controls, age-appropriate content, and a durable design, it's a must-have for parents looking to provide a safe and educational device for their children.
#
# **Top 3 products in this category:**
# 1. **Amazon Fire HD 8 Kids Edition:** This tablet comes with a 2-year worry-free warranty, free 1-year subscription to Amazon Kids, and parental controls. It's perfect for kids who need a durable and educational device.
# 2. **Apple iPad:** While more expensive, the iPad offers a wide range of educational apps and features for kids. It's a great choice for parents who prefer the Apple ecosystem.
# 3. **Samsung Galaxy Tab A:** With a kid-friendly design and parental controls, the Galaxy Tab A is another solid option for families looking for a reliable tablet for their children.
#
# **Top complaints for each product:**
# - Amazon Fire HD 8 Kids Edition: Some users mentioned that the screen brightness could be improved, and it doesn't support YouTube Red video downloads without WiFi.
# - Apple iPad: The high price point was a common complaint among users, as well as the limited app selection compared to Android devices.
# - Samsung Galaxy Tab A: Users reported issues with the navigation being sluggish compared to other tablets, and the camera quality was not as good as expected.
#
# **Worst product in the category:**
# There wasn't a specific worst product mentioned in the reviews, but it's important to consider the specific needs of your child and your budget when choosing a tablet.
#
# **Additional insights:**
# - The Amazon Fire HD 8 Kids Edition is praised for its durability, parental controls, and educational content.
# - Parents appreciate the ability to set time limits and control access to apps on the tablet.
# - Some users found workarounds for limitations in app availability, such as downloading APK files for specific apps.
#
# Overall, the Amazon Fire HD 8 Kids Edition stands out as a top choice for parents looking for a kid-friendly tablet with robust parental controls and educational content. Consider your child's needs and usage habits when making a decision on which tablet to purchase.
#
# === Summary for Category: All-New Fire HD 8 Kids Edition Tablet, 8 HD Display, 32 GB, Pink Kid-Proof Case ===
#
# When it comes to choosing the best product in the Amazon Echo category, it's important to consider the specific needs and preferences of the customer. Here's a breakdown of the top 3 products in this category based on customer reviews:
#
# 1. **Echo (White):**
#    - Key Differences: The Echo (White) is praised for its design and ease of use, but some customers have reported issues with connectivity and functionality.
#    - Unique Selling Points: It offers voice-controlled smart home features and access to Amazon's Alexa.
#    - When to Choose: Customers looking for a budget-friendly smart home device with basic functionality may choose the Echo (White).
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver:**
#    - Key Differences: The Echo Plus comes with a built-in hub for smart home devices and offers improved sound quality compared to the Echo (White).
#    - Unique Selling Points: It provides seamless integration with smart home devices and offers a more premium audio experience.
#    - When to Choose: Customers who prioritize smart home automation and audio quality may prefer the Echo Plus over other options.
#
# 3. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen:**
#    - Key Differences: The Echo Show features a screen for visual interactions and video calls, setting it apart from other Echo devices.
#    - Unique Selling Points: It offers a visual element to Alexa's capabilities, making it ideal for tasks that benefit from a screen.
#    - When to Choose: Customers looking for a smart home device with visual features, such as video calls and recipe displays, may opt for the Echo Show.
#
# **Top Complaints:**
# - Echo (White): Connectivity issues, limited functionality without a Prime membership.
# - Echo Plus: No significant negative reviews mentioned.
# - Echo Show: Limited customization options, issues with compatibility with Amazon Cloud Cam.
#
# **Worst Product:**
# - Based on customer feedback, the Echo (White) seems to have the most negative reviews due to connectivity issues and limited functionality without a Prime membership. Customers may want to avoid this product if they prioritize seamless connectivity and advanced features.
#
# **Additional Insights:**
# - Customers appreciate the ease of use and design of the Echo devices, but some have reported issues with connectivity and functionality.
# - The Echo Plus is praised for its integration with smart home devices and improved sound quality.
# - The Echo Show stands out for its visual capabilities, making it a great choice for tasks that benefit from a screen.
#
# In conclusion, when choosing an Amazon Echo device, customers should consider their specific needs, such as smart home integration, audio quality, and visual features, to select the product that best suits their preferences.
#
# === Summary for Category: All-New Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Marine Blue - with Special Offers ===
#
# **Top 3 products in this category:**
#
# 1. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen**
#    - Key Differences: This product stands out for its practicality, easy setup, good sound quality, and the added benefit of a 7" screen for visual interactions.
#    - Unique Selling Points: The Echo Show allows for video calls, HD video streaming, and on-demand security video monitoring, making it a versatile smart home device.
#    - When to Choose: Customers looking for a smart speaker with a visual display for video calls, security monitoring, and interactive features should opt for the Echo Show.
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver**
#    - Key Differences: The Echo Plus comes with a built-in hub for seamless smart home device integration and improved sound quality.
#    - Unique Selling Points: This product offers a hub for controlling smart devices, high-quality sound, and compatibility with various smart home accessories.
#    - When to Choose: Customers interested in a smart speaker with a built-in hub for easy smart home control and enhanced sound quality should choose the Echo Plus.
#
# 3. **Echo (White)**
#    - Key Differences: The Echo (White) is a more basic version of the Echo lineup, offering standard smart speaker features without the built-in hub or visual display.
#    - Unique Selling Points: This product is priced competitively and offers voice-controlled music playback, smart home control, and Alexa's functionalities.
#    - When to Choose: Customers on a budget looking for a reliable smart speaker with voice control and basic smart home capabilities should consider the Echo (White).
#
# **Top complaints for each product:**
#
# - **Amazon Echo Show**: Some customers found the lack of customization options and limited app availability frustrating, especially when it came to integrating with certain services like Amazon Cloud Cam.
# - **Amazon - Echo Plus w/ Built-In Hub - Silver**: No negative reviews mentioned for this product.
# - **Echo (White)**: Customers reported issues with connectivity, voice recognition accuracy, and limitations in functionality without a Prime membership.
#
# **Worst product in the category:**
#
# The Echo (White) received the most negative feedback, with complaints about connectivity issues, voice recognition accuracy, and limited functionality without a Prime membership. Customers should avoid this product if they prioritize seamless connectivity and advanced features.
#
# **Additional insights:**
#
# - Recurring themes in reviews include praise for the ease of setup, sound quality, and versatility of the Echo Show.
# - Notable features that impress customers include the video calling capabilities, HD video streaming, and smart home integration of the Echo Show.
# - Practical advice based on customer experiences includes ensuring compatibility with existing smart home devices and exploring the full range of features available on each product before making a purchase decision.
#
# === Summary for Category: All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Black ===
#
# Based on the reviews provided, here is a concise blog-style review article for customers looking to choose the best Amazon tablet:
#
# **Top 3 products in this category:**
#
# 1. **Amazon Fire HD 8 Tablet (16GB):**
#    - **Key Differences:** Affordable price, good battery life, clear HD display, and expandable storage.
#    - **Unique Selling Points:** Great for watching movies, checking emails, and basic web surfing.
#    - **When to Choose:** Ideal for those looking for an inexpensive tablet for entertainment purposes.
#
# 2. **Amazon Fire HD 8 Tablet (32GB):**
#    - **Key Differences:** Larger storage capacity, faster performance, and more internal memory.
#    - **Unique Selling Points:** Suitable for users who need more storage for photos and apps.
#    - **When to Choose:** Recommended for those who want a tablet with higher capacity and speed.
#
# 3. **Amazon Fire HD 10 Tablet:**
#    - **Key Differences:** Larger 10-inch screen, longer battery life, and better for watching videos.
#    - **Unique Selling Points:** Great for users who prefer a bigger screen for entertainment.
#    - **When to Choose:** Perfect for those who prioritize screen size and video quality.
#
# **Top complaints for each product:**
#
# - **Amazon Fire HD 8 (16GB):** Limited app selection, Amazon-centric interface, and some users found the screen brightness lacking.
# - **Amazon Fire HD 8 (32GB):** Limited app availability, Amazon app overload, and some users experienced slippery grip.
# - **Amazon Fire HD 10:** Shorter battery life, inability to decode certain video formats, and disappointment with customer service.
#
# **Worst product in the category:**
#
# - **Amazon Fire HDX 8.9 Tablet:** Decreasing battery life, inability to decode certain video formats, and disappointment with the screen size.
#
# **Additional insights:**
#
# - **Recurring Themes:** Users appreciate the affordability and performance of Amazon tablets for basic tasks like watching movies and checking emails.
# - **Notable Features:** Expandable storage, clear HD display, and ease of use are highlighted as positive aspects.
# - **Practical Advice:** Consider your storage needs, app preferences, and screen size requirements before choosing an Amazon tablet. Be aware of the limitations of the Amazon app store compared to Google Play Store.
#
# In conclusion, Amazon Fire HD tablets offer a range of options to suit different needs and preferences. Customers should carefully consider their usage requirements and budget constraints before making a purchase decision.
#
# === Summary for Category: Amazon - Echo Plus w/ Built-In Hub - Silver ===
#
# In the world of smart home devices, the Amazon Echo Plus stands out as a top contender. With its built-in hub and impressive sound quality, it offers a seamless experience for users looking to enhance their home automation setup. Customers have praised the Echo Plus for its ease of use, fast setup, and extensive capabilities. From controlling smart bulbs to playing music and even making calls, this device has proven to be a valuable addition to many households.
#
# One satisfied customer shared their experience of setting up the Echo Plus in their home office, where they were impressed by the sound quality and versatility of the device. They highlighted the convenience of being able to program Alexa to start their daily routine with news, weather updates, and music. The user also appreciated the device's ability to provide recipe suggestions, making cooking a breeze. Overall, they found the Echo Plus to be a fun and functional addition to their smart home setup.
#
# Another customer mentioned how the Echo Plus exceeded their expectations, especially in terms of its smart hub capabilities. They were able to easily control their smart lights, set reminders, and even enjoy music with improved sound quality. The user also noted the device's seamless integration with other smart devices in their home, making it a valuable tool for managing their daily tasks.
#
# While some users have mentioned minor frustrations with configuring music playback and account settings, the overall consensus is overwhelmingly positive. The Echo Plus has proven to be a reliable and versatile smart home device that offers a range of features to enhance the user experience. Whether you're looking to start your smart home journey or upgrade your existing setup, the Amazon Echo Plus is definitely worth considering.
#
# === Summary for Category: Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen ===
#
# Based on the reviews, the top 3 products in this category are:
#
# 1. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen**
#    - Key Differences: Features a 7" screen for visual interactions, video calls, and displaying information.
#    - Unique Selling Points: HD video, voice-activated messaging, and video calls. Useful for smart home control and entertainment.
#    - When to Choose: Ideal for those looking for a smart speaker with a screen for visual interactions, video calls, and smart home control.
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver**
#    - Key Differences: Built-in hub for smart home device control, improved sound quality.
#    - Unique Selling Points: Seamless integration with smart devices, good sound quality, and versatile functionality.
#    - When to Choose: Suitable for users interested in smart home automation and improved sound quality in a smart speaker.
#
# 3. **Echo (White)**
#    - Key Differences: Basic smart speaker functionality, limited smart home control features.
#    - Unique Selling Points: Affordable entry-level smart speaker with Alexa voice assistant.
#    - When to Choose: Budget-conscious users looking for a basic smart speaker with voice assistant capabilities.
#
# Top Complaints:
# - Echo (White): Connectivity issues, limited functionality without Prime membership.
# - Amazon - Echo Plus: No significant negative reviews mentioned.
# - Amazon Echo Show: Lack of customization options, issues with Amazon Cloud Cam integration.
#
# Worst Product:
# - The Echo (White) received the most negative feedback due to connectivity issues, limited functionality without a Prime membership, and lack of features compared to other models.
#
# Additional Insights:
# - Customers praise the Amazon Echo Show for its practicality, easy setup, good sound quality, and visual interactions.
# - Some users find the lack of customization options and issues with Amazon Cloud Cam integration frustrating.
# - The Echo Plus is recommended for its seamless integration with smart devices and improved sound quality.
#
# In conclusion, the Amazon Echo Show stands out as the top choice for users seeking a smart speaker with a screen for visual interactions, video calls, and smart home control. The Echo Plus is a great option for those interested in smart home automation and improved sound quality, while the Echo (White) is a budget-friendly choice for basic smart speaker functionality.
#
# === Summary for Category: Amazon Kindle Paperwhite - eBook reader - 4 GB - 6 monochrome Paperwhite - touchscreen - Wi-Fi - black,,, ===
#
# In the world of smart home devices, Amazon's Echo lineup has become a popular choice for many consumers. Let's take a closer look at three of the top products in this category, along with their key features and customer feedback.
#
# **Top 3 products in this category:**
#
# 1. **Echo (White):**
#    - Key Differences: The Echo is a voice-controlled speaker that connects to Alexa, Amazon's virtual assistant. It allows users to play music, control smart home devices, set alarms, and more.
#    - Unique Selling Points: The Echo offers a sleek design and easy setup, making it a versatile addition to any home.
#    - When to Choose: Customers looking for a budget-friendly smart speaker with basic functionality should consider the Echo.
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver:**
#    - Key Differences: The Echo Plus includes a built-in smart home hub, allowing for seamless integration with compatible devices. It also boasts improved sound quality compared to the standard Echo.
#    - Unique Selling Points: The Echo Plus offers advanced smart home capabilities and enhanced audio performance.
#    - When to Choose: Customers interested in building a comprehensive smart home ecosystem should opt for the Echo Plus.
#
# 3. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen:**
#    - Key Differences: The Echo Show features a 7-inch screen, enabling visual interactions with Alexa. It can display videos, photos, and even make video calls.
#    - Unique Selling Points: The Echo Show combines the functionality of a smart speaker with the visual benefits of a screen, making it ideal for tasks that require visual feedback.
#    - When to Choose: Customers seeking a more interactive and visual smart home experience should consider the Echo Show.
#
# **Top complaints for each product:**
#
# - Echo (White): Customers have reported issues with connectivity, limited functionality without a Prime membership, and difficulties with setting up smart home devices.
# - Amazon - Echo Plus w/ Built-In Hub - Silver: There are no significant negative reviews available for this product.
# - Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen: Some users have expressed dissatisfaction with the lack of customization options and connectivity issues with certain smart home devices.
#
# **Worst product in the category:**
#
# Based on customer feedback, the Echo (White) seems to have the most negative reviews, citing connectivity issues, limited functionality, and difficulties with setup as major drawbacks. Customers may want to avoid this product if they prioritize seamless connectivity and advanced features.
#
# **Additional insights:**
#
# - Recurring themes from reviews include the convenience of voice control, the versatility of smart home integration, and the importance of sound quality.
# - Notable features that impress customers include the ease of setup, the range of skills available through Alexa, and the visual interactions offered by the Echo Show's screen.
# - Practical advice based on customer experiences includes ensuring a stable Wi-Fi connection, exploring the full range of Alexa skills, and considering compatibility with existing smart home devices before making a purchase decision.
#
# In conclusion, when choosing a smart home device from Amazon's Echo lineup, customers should consider their specific needs and preferences to select the product that best suits their lifestyle and home environment.
#
# === Summary for Category: Echo (White),,,
# Echo (White),,, ===
#
# **Top 3 products in this category:**
#
# 1. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen**
#    - Key Differences: This product stands out for its practicality, easy setup, and good sound quality. It features a 7" screen that displays information and videos, making it a versatile device.
#    - Unique Selling Points: The Echo Show allows for video calls, security monitoring, and voice-activated messaging. It is recommended for those looking for a smart home device with a screen.
#    - When to Choose: Customers who value visual information, video calls, and a wide range of Alexa capabilities should choose the Echo Show.
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver**
#    - Key Differences: This product includes a built-in hub for smart home devices, making it a convenient choice for those looking to control their home automation seamlessly.
#    - Unique Selling Points: The Echo Plus offers improved sound quality, compatibility with smart bulbs, and easy setup for smart home integration.
#    - When to Choose: Customers interested in a smart hub integrated with their speaker, improved sound quality, and easy setup for smart devices should opt for the Echo Plus.
#
# 3. **Echo (White)**
#    - Key Differences: This product is known for its design and limited functionality. It may be suitable for those looking for a basic smart speaker without advanced features.
#    - Unique Selling Points: The Echo offers voice control for smart home devices and basic tasks like setting timers and alarms. It is priced competitively compared to other models.
#    - When to Choose: Customers seeking a budget-friendly smart speaker for basic tasks and smart home control should consider the Echo.
#
# **Top complaints for each product:**
#
# - Amazon Echo Show: Some customers found the lack of customization options and limited value in the screen features to be drawbacks.
# - Amazon - Echo Plus w/ Built-In Hub: No negative reviews mentioned.
# - Echo (White): Common complaints include connectivity issues, limited functionality without a Prime membership, and difficulties with setup and understanding commands.
#
# **Worst product in the category:**
#
# The Echo (White) received the most negative feedback, with customers citing connectivity problems, limited functionality without a Prime membership, and frustrations with setup and understanding commands. It is recommended to avoid this product if you are looking for a reliable and feature-rich smart speaker.
#
# **Additional insights:**
#
# - Customers appreciate the practicality and ease of setup of the Amazon Echo Show, especially for smart home integration and video calls.
# - The Amazon - Echo Plus w/ Built-In Hub is praised for its sound quality, compatibility with smart devices, and seamless setup for home automation.
# - The Echo (White) is criticized for its connectivity issues, limited functionality without a Prime membership, and difficulties with setup and understanding commands. Consider opting for a different model for a better user experience.
#
# === Summary for Category: Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers ===
#
# In the world of smart home devices, Amazon's Echo lineup has been a popular choice for many consumers. Let's take a closer look at three of the top products in this category, along with their key features and customer feedback.
#
# 1. **Echo (White):** This device is praised for its design and ease of use, but some customers have reported issues with connectivity and functionality. It is a good choice for those looking for a smart home control device, but may not be the best option for those seeking advanced features like music streaming without a Prime membership.
#
# 2. **Amazon Echo Plus w/ Built-In Hub - Silver:** Customers love the sound quality and versatility of this device, especially when paired with smart bulbs. It is a great option for those looking to start a smart home project and want a device with a built-in hub. However, some users have mentioned frustrations with music playback and configuration.
#
# 3. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen:** This device stands out for its practicality and video capabilities, making it a great addition to any kitchen or living room. Customers appreciate the screen for displaying recipes and watching videos, but some have noted limitations in customization and compatibility with certain apps.
#
# **Top Complaints:**
# - Echo (White): Connectivity issues and limited functionality without a Prime membership.
# - Echo Plus: Frustrations with music playback and configuration.
# - Echo Show: Lack of customization options and compatibility issues with certain apps.
#
# **Worst Product in the Category:**
# Based on customer feedback, the Echo (White) seems to have the most negative reviews due to connectivity issues and limited functionality without a Prime membership. Customers may want to avoid this product if they are looking for a seamless smart home experience.
#
# **Additional Insights:**
# - Customers across all products have mentioned issues with connectivity and setup, so it's important to carefully follow the instructions and troubleshoot any problems.
# - The Echo Plus is praised for its sound quality and smart home capabilities, making it a good choice for those looking to start a smart home project.
# - The Echo Show's video display and practical features make it a great addition to any kitchen or living room, despite some limitations in customization.
#
# In conclusion, when choosing a smart home device from Amazon's Echo lineup, consider your specific needs and preferences to find the best fit for your home. Each product has its own unique features and drawbacks, so it's important to weigh them carefully before making a purchase.
#
# === Summary for Category: Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case ===
#
# Based on the reviews provided, here is a concise blog-style review article for the Amazon Fire Kids Edition Tablet:
#
# **Top 3 products in this category:**
# 1. **Amazon Fire Kids Edition Tablet:** This tablet is praised for its child-friendly e-books, educational apps, and durable design. The parental controls and included warranty make it a great choice for kids.
# 2. **Sprout Cubby Tablet:** While some customers had issues with customer service, this tablet is also popular for its preloaded apps and durability.
# 3. **LeapPad:** Another popular choice for kids, the LeapPad offers parental controls and educational content, making it a great learning tool.
#
# **Top complaints for each product:**
# - **Amazon Fire Kids Edition Tablet:** Some customers mentioned issues with the charging port and the need for a specific cable.
# - **Sprout Cubby Tablet:** Complaints about customer service and durability were common among negative reviews.
# - **LeapPad:** A few customers mentioned issues with app compatibility and charging.
#
# **Worst product in the category:**
# - The Amazon Fire Kids Edition Tablet received some negative feedback regarding the need for a credit card to access certain features, which may not be suitable for all customers.
#
# **Additional insights:**
# - Customers appreciated the educational content and parental controls offered by these tablets.
# - Some customers experienced issues with app compatibility and charging, so it's important to consider these factors before making a purchase.
# - Overall, the Amazon Fire Kids Edition Tablet seems to be a popular choice for its child-friendly features and durability, making it a top recommendation for parents looking for a tablet for their kids.
#
# === Summary for Category: Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adaptive Built-in Light, PagePress Sensors, Free 3G + Wi-Fi - Includes Special Offers ===
#
# In the realm of smart home devices, Amazon's Echo lineup has been a popular choice for consumers looking to add voice-controlled convenience to their homes. In this review, we'll take a closer look at three top products in this category, along with their key features, customer feedback, and recommendations.
#
# **Top 3 products in this category:**
#
# 1. **Echo (White):** This device offers basic smart home control features and Alexa's voice assistant capabilities. However, customers have reported issues with connectivity and limited functionality without a Prime membership. It may be suitable for those looking for an entry-level smart speaker but may not be the best choice for advanced users or those seeking a robust smart home experience.
#
# 2. **Amazon Echo Plus w/ Built-In Hub - Silver:** The Echo Plus stands out with its built-in smart home hub, making it easier to connect and control compatible devices. Customers have praised its sound quality and seamless integration with smart bulbs. This product is recommended for users looking to start or expand their smart home setup without the need for additional hubs.
#
# 3. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen:** The Echo Show offers a unique visual experience with its 7" screen, allowing users to access video content, make video calls, and view security camera feeds. Customers appreciate its versatility and ease of use, making it a great addition to kitchens or living rooms. This product is ideal for those looking for a smart speaker with added visual capabilities.
#
# **Top complaints for each product:**
#
# - **Echo (White):** Connectivity issues, limited functionality without a Prime membership.
# - **Amazon Echo Plus w/ Built-In Hub - Silver:** No significant negative reviews mentioned.
# - **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen:** Lack of customization options, issues with compatibility with Amazon Cloud Cam.
#
# **Worst product in the category:**
#
# The Echo (White) stands out as the least favored product in this category due to its reported connectivity issues and limited functionality without a Prime membership. Customers have expressed frustration with its performance, making it a product to avoid for those seeking a reliable smart home experience.
#
# **Additional insights:**
#
# - Customers have highlighted the importance of seamless connectivity and ease of use when choosing a smart home device.
# - Sound quality, integration with smart home devices, and visual capabilities are key factors that impress customers.
# - Practical advice includes researching compatibility with existing smart home devices and considering the level of functionality needed before making a purchase decision.
#
# In conclusion, when choosing a smart home device from Amazon's Echo lineup, it's essential to consider your specific needs and preferences to find the product that best suits your requirements. Whether you're looking for basic voice control, smart home hub integration, or visual capabilities, there's a product in the Echo lineup to meet your needs.
#
# === Summary for Category: Kindle Voyage E-reader, 6 High-Resolution Display (300 ppi) with Adaptive Built-in Light, PagePress Sensors, Wi-Fi - Includes Special Offers ===
#
# **Top 3 products in this category:**
#
# 1. **Amazon Echo Show Alexa-enabled Bluetooth Speaker with 7" Screen**
#    - **Key Differences:** This product stands out for its practicality, easy setup, good sound quality, and the added benefit of a 7" screen. It allows for video calls, security monitoring, and a variety of other features.
#    - **When to Choose:** Customers looking for a smart device with a screen for added functionality, such as video calls, security monitoring, and visual aids, should opt for the Amazon Echo Show.
#
# 2. **Amazon - Echo Plus w/ Built-In Hub - Silver**
#    - **Key Differences:** This product offers a built-in hub for smart home devices, good sound quality, and versatility in controlling various devices. It also comes with a sleek design and ease of use.
#    - **When to Choose:** Customers interested in a smart hub with good sound quality and the ability to control smart home devices seamlessly should consider the Amazon Echo Plus.
#
# 3. **Echo (White)**
#    - **Key Differences:** This product is known for its design, on/off timer functionality, and smart home control capabilities. However, it has limitations in terms of features and connectivity.
#    - **When to Choose:** Customers looking for a budget-friendly option with basic smart home control features and a sleek design can opt for the Echo (White).
#
# **Top complaints for each product:**
#
# - **Amazon Echo Show:** Some customers found the lack of customization options and issues with compatibility frustrating.
# - **Amazon - Echo Plus w/ Built-In Hub - Silver:** No negative reviews mentioned.
# - **Echo (White):** Customers reported connectivity issues, limited features, and difficulties with voice recognition.
#
# **Worst product in the category:**
#
# The Echo (White) received the most negative feedback, with complaints about connectivity issues, limited features, and voice recognition problems. Customers should avoid this product if they require advanced smart home control capabilities and seamless connectivity.
#
# **Additional insights:**
#
# - Customers appreciate the practicality and ease of setup of the Amazon Echo Show, especially for video calls and security monitoring.
# - The Amazon - Echo Plus w/ Built-In Hub - Silver is praised for its versatility in controlling smart home devices and its sleek design.
# - The Echo (White) falls short in terms of connectivity and advanced features, making it less appealing for customers seeking a comprehensive smart home solution.
#
# Based on customer reviews, it is recommended to choose the Amazon Echo Show for its added screen functionality, the Amazon - Echo Plus w/ Built-In Hub - Silver for its smart hub capabilities, and to avoid the Echo (White) due to its limitations.
